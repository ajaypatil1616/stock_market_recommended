# %%
# from fuzzywuzzy import fuzz

# def extract_ticker_name(stock_names):
#     stock_ticker_collection = db['stock_ticker']  
#     tickers = []  
    
#     for stock_name in stock_names:
    
#         stock_name_normalized = ''.join(e for e in stock_name.upper() if e.isalnum())
        
        
#         found_match = False
        
#         for ticker_doc in stock_ticker_collection.find():
#             ticker = ticker_doc['Ticker']
#             ticker_name_normalized = ''.join(e for e in ticker.upper() if e.isalnum())
            
#             match_score = fuzz.partial_ratio(stock_name_normalized, ticker_name_normalized)
            
#             if match_score > 80: 
#                 tickers.append(ticker) 
#                 found_match = True
#                 break

#         if not found_match:
#             tickers.append(None)
    
#     return tickers

# %%
# Example list of stock names (this could be companies like 'Apple', 'Microsoft', or ticker symbols like 'AAPL', 'MSFT')
stock_names = ['Bharti Airtel Limited',
 'Ashok Leyland Limited',
 'Aurobindo Pharma Limited',
 'Arex Industries Ltd.',
 'Sanwaria Agro Oils Limited',
 'Almondz Global Securities Limited',
 'Adinath Textiles Ltd',
 'State Bank of India',
 'Bharat Petroleum Corporation Limited',
 'McNally Bharat Engineering Company Limited',
 'Bank of Maharashtra',
 'D. B. Corp Limited',
 'Bosch Limited',
 'Bharat Heavy Electricals Ltd.',
 'IDBI Bank Limited',
 'IRB Infrastructure Developers Limited',
 'Dabur India Limited',
 'TCI Developers Limited',
 'New Delhi Television Limited',
 'Ishita Drugs & Industries Ltd',
 'Gateway Distriparks Limited',
 "Dr. Reddy's Laboratories Limited",
 'India Power Corporation Limited',
 'DLF Limited',
 'Deepak Spinners Limited',
 'Danlaw Technologies India Limited',
 'Vipul Dye Chem Ltd.',
 'Vadilal Dairy International Ltd.',
 'Trimurthi Limited',
 'Thakkers Developers Ltd',
 'TATA MOTORS LTD - DVR',
 'SUPERSTAR DISTILLERIES & FOODS',
 'Shri Dinesh Mills Limited',
 'Radhe Developers (India) Ltd.',
 'Proto Developers & Technologies Limited',
 'Prabhat Dairy Limited',
 'ND Metal Industries Ltd',
 'MODERN DENIM LTD.',
 'Mangalam Drugs & Organics Limited',
 'Mahindra Lifespace Developers Limited',
 'Landmark Property Development Company Limited',
 'Kaushalya Infrastructure Development Corporation Limited',
 'IRB Infrastructure Developers Limited',
 'Interworld Digital Ltd.',
 'Indian Toners & Developers Ltd.',
 'India Lease Development Limited',
 'Housing Development and Infrastructure Limited',
 'Housing Development & Infrastructure Limited',
 'Housing Development Finance Corporation Limited',
 'Housing Development Finance Corporation Limited',
 'Golkunda Diamonds & Jewellery Limited',
 'Goenka Diamond and Jewels Limited',
 'Ess Dee Aluminium Limited',
 'Energy Development Company Limited',
 'E.I.D.- Parry (India) Limited',
 'Keltech Energies Limited',
 'Schneider Electric Infrastructure Limited',
 'Eastern Silk Industries Ltd.',
 'Tata Elxsi Limited',
 'Swaraj Engines Limited',
 'Sterling International Enterprises Ltd.',
 'Sequel e-Routers Ltd.',
 'Rural Electrification Corporation Limited',
 'Piramal Enterprises Limited',
 'M.K. Exim (India) Limited',
 'Jaybharat Textiles And Real Estate Limited',
 'Indiabulls Real Estate Limited',
 'Everonn Education Limited',
 'Essel Propack Limited',
 'Entegra Limited',
 'Emmessar Biotech & Nutrition Limited',
 'E.com Infotech India Ltd.',
 'Bharat Electronics Limited',
 'Adani Ports and Special Economic Zone Limited',
 'Zicom Electronic Security Systems Limited',
 'Anukaran Commercial Enterprises Ltd.',
 'Oracle Financial Services Software Limited',
 'LIC Housing Finance Limited',
 'Fortune Financial Services (India) Limited',
 'Sundram Fasteners Limited',
 'Sundaram Finance Limited',
 'Sita Shree Food Products Limited',
 'Relaxo Footwears Limited',
 'Rashtriya Chemicals And Fertilizers Limited',
 'PTC India Financial Services Limited',
 'Power Finance Corporation Limited',
 'Nikki Global Finance Limited',
 'Muthoot Finance Limited',
 'Max Financial Services Limited',
 'Magma Fincorp Limited',
 'KZ Leasing & Finance Ltd.',
 'Integrated Financial Services Limited',
 'Hindustan Foods Limited',
 'Hilton Metal Forging Limitied',
 'Gowra Leasing & Finance Ltd.',
 'Geefcee Finance Limited',
 'Force Motors Ltd.',
 'Foods & Inns Ltd.',
 'Filmcity Media Ltd.',
 'Foundry Fuel Products Ltd.',
 'The Fertilisers And Chemicals Travancore Limited',
 'Arora Fibres',
 'Ajwa Fun World & Resort Ltd',
 'Ad-Manum Finance Ltd',
 'Subway Finance & Investment Co., Ltd.',
 'SIYARAM PODDAR FINANCE & TRADI',
 'SHERATON PROPERTIES & FINANCE',
 'SAMPARK TRADING & FINANCE LTD.',
 'Nivedita Mercantile & Financing Ltd.',
 'Wall Street Finance Ltd.',
 'Weizmann Forex Limited',
 'WEIZMANN FOREX LTD.',
 'Wallfort Financial Services Limited',
 'Voith Paper Fabrics India Limited',
 'VBC Ferro Alloys Limited',
 'Vax Housing Finance Corporation Ltd.',
 'Upasana Finance Ltd',
 'Tirupati Foam Limited',
 'Gujarat State Petronet Limited',
 'Gayatri Projects Limited',
 'GAIL (India) Limited',
 'TAJGVK Hotels & Resorts Limited',
 'Power Grid Corporation of India Limited',
 'Oil and Natural Gas Corp. Ltd.',
 'Vardhman Holdings Limited',
 'Hindustan Unilever Limited',
 'Hindustan Petroleum Corporation Limited',
 'Hindustan Construction Company Limited',
 'Huhtamaki PPL Limited',
 'International Travel House Limited',
 'Hind Rectifiers Limited',
 'Hester Biosciences Ltd',
 'Hindustan Construction Company Limited',
 'Gujarat Hotels Ltd.',
 'Graviss Hospitality Limited',
 'Benares Hotels Limited',
 'Zenith Healthcare Ltd',
 'WONDERLA HOLIDAYS LTD',
 'WH Brady & Company Limited',
 'THE BYKE HOSPITALITY LTD.',
 'Syncom Healthcare Limited',
 'Sunil Hitech Engineers Ltd.',
 'STERLINH6.BO',
 'Sterling Holiday Resorts (India) Limited',
 'Shree Hari Chemicals Export Limited',
 'Shree Ganesh Jewellery House (I) Limited',
 'Royal Orchid Hotels Limited',
 'Royal Orchid Hotels Limited',
 'Jubilant Industries Limited',
 'J.Kumar Infraprojects Limited',
 'JVL Agro Industries Ltd',
 'Jain Irrigation Systems Limited',
 'Jai Balaji Industries Ltd.',
 'Zodiac-JRD-MKJ Limited',
 'State Bank of Bikaner & Jaipur',
 'State Bank of Bikaner & Jaipur',
 'PC JEWELLER LIMITE INR10',
 'Jyoti Ltd.',
 'Jyothy Laboratories Limited',
 'Jubilant FoodWorks Limited',
 'Jubilant FoodWorks Limited',
 'Jubilant Life Sciences Limited',
 'JSW Steel Limited',
 'JSW STEEL LTD.',
 'JSW Energy Limited',
 'JPT Securities Ltd.',
 'Jaiprakash Power Ventures Limited',
 'Jaiprakash Power Ventures Limited',
 'Jindal Poly Investment and Finance Company Limited',
 'Jaypee Infratech Limited',
 'JK Tyre & Industries Limited',
 'JK Paper Limited',
 'Jain Irrigation Systems Limited',
 'Jindal Cotex Limited',
 'Jindal Saw Limited',
 'Jetking Infotrain Limited',
 'Jet Airways (India) Ltd.',
 'JCT Ltd.',
 'JBF Industries Limited',
 'JAMES WARREN TEA LTD',
 'Jaihind Projects Limited',
 'Jagsonpal Finance & Leasing Ltd',
 'Jagran Prakashan Limited',
 'JM FINANCIAL INR1',
 'Divya Jyoti Industries Ltd',
 'B.J.DUPLEX BOARDS LTD.',
 'JAGSONPAL PHARMACE INR5',
 'Jamna Auto Industries Limited',
 'Jai Corp Limited',
 'JAI MATA INDUSTRIES LTD.',
 'Jullundur Motor Agency (Delhi) Limited',
 'JYOTI STRUCTURES INR2',
 'Jyoti Resins & Adhesives Ltd.',
 'JUPITER INFOMEDIA LTD.',
 'JENSON & NICHOLSON (INDIA) LTD',
 'JKLAKSHMI*',
 'Just Dial Limited',
 'Kintech Renewables Limited',
 'JAY ENERGY AND S.ENERGIES LTD.',
 'J. Kumar Infraprojects Limited',
 'Jayatma Spinners Limited',
 'Jayant Mercantile Co. Ltd.',
 'R J BIO-TECH LTD',
 'JINDAL WORLDWIDE LTD.',
 'The Jammu and Kashmir Bank Limited',
 'JINDAL STEEL & POWER LTD.',
 'JINDAL POLY FILMS LTD.',
 'JAIPRAKASH ASSOCIATES LTD.',
 'Kashyap Tele-Medicines Limited',
 'VERONICA PRODUCTION LTD',
 'JUST DIAL LTD INR10',
 'JAIN IRRIGATION SYSTEMS LTD.',
 'JPASSOCIAT6.BO',
 'Jeevan Scientific Technology L',
 'Florence Investech Limited',
 'THE JAMMU & KASHMIR BANK LIMITE',
 'James Hotels Ltd',
 'Jet Infraventure Limited',
 'JINDAL SAW LTD.',
 'JAMNA AUTO INDUSTRIES LIMITED',
 'JSW STEEL LTD 0.01% PRF 15/03/1',
 'Jenburkt Pharmaceuticals Ltd.',
 'C.J. Gelatine Products Ltd.',
 'JCT ELECTRONICS INR1.00',
 'J. L. Morison (India) Limited',
 'PC Jeweller Limited',
 'JATTASHANKAR INDUSTIES LTD.',
 'JSW HOLDINGS LIMIT INR10',
 'JAYKAY ENTERPRISES LTD.',
 'Jindal Stainless Limited',
 'Jaysynth Dyestuff India Ltd.',
 'JMC PROJECTS (INDIA) LTD.',
 'JTL INFRA LTD.',
 'Narbada Gems And Jewellery Ltd',
 'Tara Jewels Limited',
 'Jay Ushin Limited',
 'JSW Energy Limited',
 'JAYASWAL NECO IND INR10',
 'JUMBO BAG LTD.',
 'SAI JEEVADHARA FINANCE LIMITED',
 'JUMBO FINANCE LTD.',
 'JBF Industries Limited',
 'J.K. Cement Limited',
 'JUMBO-BZ.NS',
 'JK PAPER LIMITED',
 'Jindal Hotels Ltd',
 'JSL6.BO',
 'Goldman Sachs Junior BeES ETF',
 'Jagson Airlines Ltd.',
 'JINDAL COTEX LIMITED',
 'JAICORPLTD6.BO',
 'A.J.BROTHERS LTD.',
 'JIK INDUSTRIES LTD.',
 'LYPSA GEMS & JEWELLERY LTD',
 'Josts Engineering Company Ltd',
 'Jindal Photo Limited',
 'JAI BALAJI INDUSTRIES LIMITED',
 'Jaihind Synthetics Limited',
 'ATLAS JEWELLERY INDIA LIMITED',
 'JK TYRE & INDUSTRIES LTD.',
 'JAGSONPAL PHARMACEUTICALS LTD.',
 'JMD Ventures Limited',
 'JAY BHARAT MARUTI LTD.',
 'JAGDAMD.BO',
 'Joy Realty Ltd',
 'JMP CASTINGS LTD.',
 'Jayant Agro-Organics Limited',
 'PC JEWELLER LTD.',
 'Jai Balaji Industries Limited',
 'Jindal Worldwide Limited',
 'JK PAPER LTD.',
 'JIK INDUSTRIES INR10',
 'JMDE PACKAGING & REALTIES LTD.',
 'Jai Mata Glass Ltd.',
 'JMT AUTO LIMITED',
 'JSW Holdings Limited',
 'JINDAL PHOTO LTD.',
 'JK Lakshmi Cement Limited',
 'J. TAPARIA PROJECTS LTD',
 'JOLLY RIDES LTD.',
 'Jiya Eco-Products Limited',
 'JISLJALEQS6.BO',
 'JAIHIND PROJECTS LIMITED',
 'Shree Jagdambe Paper Mills Ltd.',
 'KM Sugar Mills Ltd.',
 'Shree Krishna Paper Mills & Industries Ltd.',
 'K.P.R. Mill Limited',
 'KPIT Technologies Limited',
 'Kotak Mahindra Bank Limited',
 'Konark Synthetic, Ltd.',
 'SONA KOYO STEERING SYSTEMS LTD',
 'Shree Karthik Papers Ltd.',
 'Kuwer Industries Limited',
 'Kunststoffe Industries',
 'Karnataka Bank Ltd.',
 'Kesar Terminals & Infrastructure Limited',
 'KSK Energy Ventures Limited',
 'KSK Energy Ventures Limited',
 'KSS Limited',
 'Kaveri Seed Company Limited',
 'Kaveri Seed Company Limited',
 'Krebs Biochemicals & Industries Ltd',
 'Kothari Products Limited',
 'Kothari Products Ltd',
 'Kothari Sugars and Chemicals Limited',
 'Kotak Mahindra Bank Limited',
 'Kopran Limited',
 'Kopran Limited',
 'Koffee Break Pictures Limited',
 'KOA Tools India Limited',
 'KNR Constructions Limited',
 'KNR Constructions Limited.',
 'KNITWORTH EXPORTS LTD.',
 'KLK Electrical Ltd',
 'Kitex Garments Limited',
 'Kirloskar Pneumatic Company Ltd',
 'Kirloskar Oil Engines Limited',
 'KIRAN SYNTEX LTD.',
 'Kilpest India Ltd.',
 'Kilburn Office Automation Ltd.',
 'Khoday India Limited',
 'Kirloskar Brothers Investments Ltd.',
 'Khandwala Securities Limited',
 'Khaitan (India) Ltd.',
 'Karuturi Global Limited',
 'Kesar Enterprises Limited',
 'Kennametal India Limited',
 'KENGOLD (INDIA) LTD.',
 'Kemp & Co. Ltd',
 'KEC International Limited',
 'KDDL Limited',
 'K.C.P. Sugar and Industries Corporation Limited',
 'The KCP Limited',
 'Kaycee Industries Ltd.',
 'Shri Keshav Cements and Infra Limited',
 'Katare Spinning Mills Ltd.',
 'G.K. Consultants Limited',
 "Eskay K'n'IT (India) Limited",
 'Everest Kanto Cylinder Limited',
 'Dai-Ichi Karkaria Limited',
 'ABM Knowledgeware Limited',
 'Kriti Industries (India) Ltd.',
 'KIC Metaliks Ltd.',
 'KSL and Industries Ltd',
 'CONSORTEX KARL DOELITZCH (INDI',
 'Kilburn Chemicals Limited',
 'Kaira Can Company Limited',
 'Kalyani Steels Limited',
 'KUSHAL TRADELINK LTD',
 'KANEL INDUSTRIES LIMITED',
 'Kansai Nerolac Paints Limited',
 'KANDAGIRI SPINNING MILLS LTD.',
 'S. Kumars Nationwide Ltd.',
 'KALYANI INVESTMENT COMPANY LIMI',
 'MRF Limited',
 'Tata Steel Limited',
 'SpiceJet Limited',
 'Reliance Power Limited',
 'Reliance Industries Limited',
 'NOCIL Limited',
 'Indo Count Industries Limited',
 'Warner Multimedia Ltd.',
 'Walchand Peoplefirst Limited',
 'Tata Consultancy Services Limited',
 'Transport Corp. of India Ltd.',
 'Surana Industries Limited',
 'Stanpacks (India) Limited',
 'Sasken Technologies Limited',
 'Shree Renuka Sugars Limited',
 'Reliance Infrastructure Limited',
 'Reliance Capital Limited',
 'Rain Industries Limited',
 'Pratibha Industries Ltd.',
 'Praj Industries Limited',
 'Polygenta Technologies Limited',
 'Olympic Oil Industries Ltd.',
 'Nicco Corporation Limited',
 'MPIL Corporation Limited',
 'Maruti Suzuki India Limited',
 'Lupin Limited',
 'Infosys Limited',
 'Indraprastha Medical Corp. Ltd.',
 'Cairn India Limited',
 'Zydus Wellness Limited',
 'Zenotech Laboratories Limited',
 'Zenith Birla (India) Limited',
 'Yes Bank Limited',
 'Yash Papers Limited',
 'Xpro India Limited',
 'Wipro Ltd.',
 'AYM Syntex Limited',
 'Voltas Limited',
 'Vishal Malleables Ltd.',
 'Visaka Industries Limited',
 'Vardhaman Laboratories Ltd.',
 'Vantage Corporate Services Ltd.',
 'UT Ltd.',
 'Usher Agro Limited',
 'Unistar Multimedia Limited',
 'UFO Moviez India Limited',
 'Uflex Limited',
 'TV18 Broadcast Limited',
 'Triton Valves Ltd',
 'Trigyn Technologies Limited',
 'Tricom India Limited',
 'Trent Limited',
 'Tide Water Oil Co. (India), Ltd.',
 'Tech Mahindra Limited',
 'Tata Motors Limited',
 'Tata Chemicals Limited',
 'Tata Chemicals Limited',
 'Sun Pharmaceutical Industries Limited',
 'Sujana Universal Industries Limited',
 'Sudev Industries Ltd.',
 'Subros',
 'Sturdy Industries Ltd',
 'Spice Islands Apparels Ltd.',
 'The South Indian Bank Limited',
 'Softsol India Ltd.',
 'Sky Industries Limited',
 'Shukra Bullions Ltd.',
 'SKF India Limited',
 'Simplex Projects Ltd.',
 'Siemens Limited',
 'SHUKUN CONSTRUCTION LTD.',
 'Shree Cement Limited',
 'Radha Madhav Corp. Ltd.',
 'Muthoot Capital Services Ltd.',
 'Murli Industries Ltd.',
 'MPHASIS6.BO',
 'MosChip Semiconductor Technology Limited',
 'Mindtree Limited',
 'Minda Industries Limited',
 'Megasoft Limited',
 'MCLEOD RUSSEL INDIA LTD.',
 'UNITED SPIRITS INR10',
 'Magnum Ventures Limited',
 'Mafatlal Industries Limited',
 'Sri Adhikari Brothers Television Network Limited',
 'Raj Television Network Ltd.',
 'Pritish Nandy Communications Ltd',
 'NTPC Limited',
 'Nile Ltd.',
 'Nettlinx Ltd',
 'NCL Industries Limited',
 'NBCC (India) Limited',
 'National Peroxide Limited',
 'NEW SAGAR TRADING CO.LTD.',
 'The United Nilgiri Tea Estates Company Limited',
 'Sun TV Network Ltd',
 'Sri Nachammai Cotton Mills Limited',
 'Smartlink Network Systems Limited',
 'Shree Rama Newsprint Limited',
 'Pritish Nandy Communications Ltd.',
 'NTPC Ltd.',
 'Npr Finance Ltd.',
 'Nova Iron & Steel Ltd.',
 'N2N TECHNOLOGIES LIMITED',
 'NMDC Limited',
 'Nitin Spinners Ltd.',
 'Nitco Limited',
 'Nirlon Ltd.',
 'Niraj Cement Structurals Ltd',
 'Nila Infrastructures Ltd',
 'NIJJER AGRO FOODS LTD.',
 'NIIT Technologies Limited',
 'NIIT Limited',
 'Nihar Info Global Ltd',
 'Nidhi Granites Limited',
 'NHPC Limited',
 'N.G. Industries Limited',
 'National Fertilizers Ltd.',
 'Neyveli Lignite Corporation Limited',
 'Monarch Networth Capital Limited',
 'Nelco Limited',
 'Nelcast Limited',
 'Nelcast Limited',
 'Neelkanth Rockminerals Ltd.',
 'North Eastern Carrying Corporation Limited',
 'Neelamalai Agro Industries Ltd.',
 'Steel Authority of India Limited',
 'Container Corporation of India Limited',
 'Unique Organics Ltd.',
 'Union Bank of India',
 'The Tinplate Company Of India Limited',
 'SORIL Infra Resources Limited',
 'Store One Retail India Ltd',
 'The Shipping Corporation of India Limited',
 'Raj Oil Mills Limited',
 'Oxford Industries Ltd',
 'OVOBEL FOODS LTD.',
 'The Oudh Sugar Mills Limited',
 'Oscar Investments Ltd.',
 'ORIENT PRESS LTD.',
 'ORIENT BELL LIMITED',
 'Organic Coatings Ltd.',
 'Orchid Pharma Limited',
 'Orbit Corporation Limited',
 'Omnitech Infosolutions Limited',
 'OMKAR SPECIALITY CHEMICALS LTD',
 'Omkar Overseas Ltd',
 'Omaxe Limited',
 'Omaxe Ltd.',
 'Omax Autos Limited',
 'OK Play India Limited',
 'Oil India Limited',
 'Oil India Limited',
 'OCL India Limited',
 'Oberoi Realty Limited',
 'MARUTI ORGANICS LTD.',
 'Multi Commodity Exchange of India Limited',
 'Motilal Oswal MOSt Shares Midcap 100 ETF',
 'La Opala RG Limited',
 'Lahoti Overseas Limited',
 'Indian Oil Corporation Limited',
 'Indian Overseas Bank',
 'GKB Ophthalmics Ltd',
 'Central Bank of India',
 'Birla Cable Limited',
 'Bank of India Limited',
 'Bang Overseas Limited',
 'Bang Overseas Ltd.',
 'Aksh Optifibre Limited',
 'Automobile Corp. of Goa Ltd.',
 'Aban Offshore Limited',
 'Onward Technologies Limited',
 'Ocean Agro (India) Limited',
 'Optimus Finance Limited',
 'OXIDES & SPECIALITIES LTD.',
 'GULF OIL LUBRICANTS INDIA LTD',
 'SHIV-VANI-EQ.NS',
 'SABERO ORGANICS GUJRAT',
 'Transport Corporation of India Limited',
 'MCX6.BO',
 'ORIENT PAPER & INDUSTRIES LTD.',
 'ORNTSYN.BO',
 'SBT6.BO',
 'ORBIT MULTIMEDIA LTD.',
 'BANK OF BARODA',
 'MANSINGHKA OIL PRODUCTS LTD.',
 'CONCOR4.BO',
 'Sahara One Media and Entertainment Limited',
 'Orient Bell Limited',
 'OPTIEMUS INFRACOM LTD',
 'Ortin Laboratories Ltd',
 'ORBIT EXPORTS LTD INR10',
 'SVOGL Oil Gas And Energy Limit',
 'TUBEINVEST6.BO',
 'SVOGL Oil Gas and Energy Limited',
 'DOLPHIN OFFSHORE ENTERPRISES (',
 'Quintegra Solutions Limited',
 'Union Quality Plastics Limited',
 'Quintegra Solutions Limited',
 'Quick Heal Technologies Limited',
 'QUASAR INDIA LTD',
 'QUANTUM BUILD-TECH LTD',
 'Quantum Gold ETF',
 'QUINTEGRA SOLUTIONS LTD.',
 'Quantum Digital Vision India Ltd.',
 'Quantum Index ETF',
 'Quantum Mutual Fund - Quantum Index Fund',
 'QPRO INFOTECH LTD.',
 'Quick Heal Technologies Limite',
 'Quantum Mutual Fund - Quantum Gold Fund',
 'QUADRANT TELEVENTURES LIMITED',
 'QUEST SOFTECH (INDIA) LTD',
 'Ruchi Strips & Alloys Ltd.',
 'Ruchi Soya Industries Limited',
 'Ritesh Properties and Industries Ltd.',
 'RFL International Ltd',
 'Rapicut Carbides Ltd.',
 'Indoco Remedies Limited',
 'GOKUL REFOILS & SO INR2',
 'Coastal Roadways Limited',
 'BSEL Infrastructure Realty Limited',
 'Texmaco Rail & Engineering Limited',
 'SVC Resources Ltd.',
 'Sunteck Realty Limited',
 'Shree Steel Wire Ropes Ltd.',
 'Shree Rajasthan Syntex Ltd.',
 'Samkrg Pistons and Rings Limited',
 'Uttam Value Steels Limited',
 'Uttam Galva Steels Limited',
 'Ushdev International Limited',
 'Usha Martin Limited',
 'UPL*',
 'Universal Starch Chem Allied Ltd.',
 'Universal Prime Aluminium Ltd.',
 'Universal Arts Ltd.',
 'United Textiles Limited',
 'Unitech Limited',
 'Uniply Industries Limited',
 'Uniphos Enterprises Ltd.',
 'Uni Abex Alloy Products Ltd.',
 'Usha Martin Education & Solutions Limited',
 'The Ugar Sugar Works Limited',
 'Sinnar Bidi Udyog Ltd.',
 'City Union Bank Limited',
 'Carborundum Universal Limited',
 'Barak Valley Cements Limited',
 'Vybra Automet Ltd.',
 'Vyapar Industries Ltd.',
 'V.S.T. Tillers Tractors Limited',
 'VST Industries Limited',
 'VOLTAS6.BO',
 'Voltas Ltd.',
 'Voltamp Transformers Limited',
 'Vivid Global Industries Limited',
 'Visagar Polytex Ltd.',
 'Ed & Tech international Limited',
 'Virtualsoft Systems Ltd',
 'VIP Industries Limited',
 'Vinyoflex Ltd.',
 'Vimta Labs Limited',
 'Vijay Solvex Ltd',
 'Videocon Industries Limited',
 'Vesuvius India Limited',
 'Venlon Enterprises Limited',
 'Venkat Pharma Ltd',
 'Veer Energy & Infrastructure Ltd',
 'Vardhman Industries Limited',
 'Valuemart Info Technologies Ltd.',
 'Swasti Vinayaka Synthetics Limited',
 'Spectacle Ventures Limited',
 'SHIVANI VANASPATI LTD.',
 'Royal Cushion Vinyl Products',
 'The Lakshmi Vilas Bank Limited',
 'IPRU2296.BO',
 'Hotel Leelaventure Limited',
 'Hotel Leelaventure Limited',
 'Hindustan Media Ventures Limited',
 'GeeCee Ventures Ltd',
 'Barak Valley Cement Ltd.',
 'VISHVPRABHA TRADING LTD.',
 'Virat Leasing Limited',
 'Silicon Valley Infotech Limited',
 'Siddha Ventures Ltd',
 'VLS Finance Limited',
 'JYOTI POLY VINYL LTD.',
 'VISU INTERNATIONAL INR10',
 'Vikas Granaries Ltd',
 'VARDHMAN TEXTILES LIMTED',
 'VALECHA ENGINEERIN INR10',
 'Vidhi Specialty Food Ingredients Limited',
 'VKJ INFRADEVELOPERS LTD',
 'VSF Projects Limited',
 'VRL Logistics Limited',
 'VIDARBHA IRON & STEEL CORPORAT',
 'VINDHYA TELELINKS LTD.',
 'VARDHMAN POLYTEX INR10',
 'VISHVAKIRTI INVESTMENT LTD.',
 'Calcom Visions Ltd.',
 'VINADITYA TRADING CO.LTD.',
 'VST INDUSTRIES LTD.',
 'SHREE VINDHYA PAPER MILLS LTD.',
 'The Victoria Mills Limited',
 'VCU DATA MANAGEMENT LTD',
 'GEECEE VENTURES LIMITED',
 'HOTELEELA6.BO',
 'VBC Industries Ltd.',
 'AXONFIN.BO',
 'VAIBHAV GLOBAL LTD',
 'Valecha Engineering Limited',
 'Vama Industries Ltd.',
 'UTTAM VALUE STEELS LTD.',
 'VERONICA LABORATORIES LTD.',
 'Morgan Ventures Limited',
 'VCCL Ltd.',
 'Virat Crane Industries Ltd.',
 'Hinduja Ventures Limited',
 'VXL INSTRUMENTS LTD.',
 'VINAYAK VANIJYA LTD.',
 'VARDHMAN SPECIAL STEELS LIMITED',
 'VIMTA LABS LTD.',
 'Vaghani Techno-Build Limited',
 'VOLGA AIR TECHNICS LTD.',
 'VIRALSYN.BO',
 'SHREEASHTA6.BO',
 'Viaan Industries Limited',
 'VIRINCHI PP',
 'VIKAS ECOTECH LIMI INR1',
 'SPEC VENTURES LTD INR1',
 'VORA CONSTRUCTIONS LTD.',
 'V2 RETAIL LTD.',
 'CHAKAN VEGOILS LTD.',
 'SUNDARAM ASSET MAN MICRO CAP VI',
 'Vikram Thermo (India) Ltd',
 'VTXIND-BE.NS',
 'TECHNVISION VENTURES LTD.',
 'VISION ORGANICS LTD.',
 'VENMAX DRUGS AND PHARMACEUTICA',
 'VIPCORP.BO',
 'DOON VALLEY RICE LTD.',
 'AADHAAR VENTURES INDIA LTD.',
 'Vippy Spinpro Ltd.',
 'VOGUE TEXTILES LTD.',
 'Vamshi Rubber Limited',
 'V-Mart Retail Limited',
 'GeeCee Ventures Limited',
 'VMS INDUSTRIES LTD.',
 'VINYL CHEMICALS (INDIA) LTD.',
 'Vinyl Chemicals India Ltd.',
 'Gujarat Narmada Valley Fertilizers & Chemicals Limited',
 'VTXIND.NS',
 'Vesuvius India Limited',
 'VATSA EDUCATIONS LTD.',
 'V-Guard Industries Limited',
 'Vaibhav Global Limited',
 'VALUE INDUSTRIES LIMITED',
 'VISESH INFOTECNICS LTD.',
 'Vadilal Industries Limited',
 'VELVETTE INTERNATIONAL PHARMA',
 'SWASTI VINAYAKA ART AND HERITA',
 'VHCL INDUSTRIES LTD.',
 'VANTEL TECHNOLOGIES LTD.',
 'UTTAM VALUE STEELS INR1',
 'IPRU8496.BO',
 'VIMAL OIL & FOODS LTD.',
 'VIDEOCON INDUSTRIES LIMITED',
 'VARDHMAN SPECIAL STEELS LTD.',
 'VATSA MUSIC LTD.',
 'AVTIL ENTERPRISE LTD',
 'Vaswani Industries Limited',
 'SOFTRAK VENTURE INVESTMENT LTD',
 'PVP Ventures Ltd',
 'Tatia Global Venture Ltd.',
 'GLOBAL VECTRA HELI INR10',
 'Welcast Steels Ltd.',
 'WPIL Limited',
 'Wisec Global Limited',
 'Wipro Limited',
 'Winsome Textile Industries Ltd.',
 'WINRO COMMERCIAL (INDIA) LTD.',
 'Wheels India Limited',
 'Welterman International Limited',
 'Welspun India Ltd.',
 'Wanbury Limited',
 'WABCO INDIA LTD.',
 'T Spiritual World Ltd',
 'Todays Writing Instruments Limited',
 'Ram Ratna Wires Ltd',
 'India Steel Works Limited',
 'Inox Wind Limited',
 'SORIL Holdings and Ventures Limited',
 'Hindustan Tin Works Ltd.',
 'First Winner Industries Limited',
 'First Winner Industries Limited',
 'Borosil Glass Works Limited',
 'ATLANTSP.BO',
 'W W TECHNOLOGY HOLDINGS LTD.',
 'WILLIAMSON MAGOR & COMPANY LTD',
 'WINDSOR MACHINES INR2',
 'CREATIVE WORLD TELEFILMS LTD.',
 'GG Dandekar Machine Works Ltd.',
 'Welspun India Limited',
 'WESTERN INDIA COTTONS LTD.',
 'Websol Energy System Limited',
 'Ozone World Limited',
 'KRISHNA ENGINEERING WORKS LTD.',
 'WELSPUN SYNTEX',
 'NEWEVER TRADE WINGS LTD',
 'Lakshmi Automatic Loom Works Limited',
 'WATERBASE LTD.',
 'Hindustan Wires Limited',
 'WINY COMMERCIAL AND FISCAL SER',
 'Wabco India Limited',
 'WEST COAST PAPER M INR2.00',
 'WAGEND INFRA VENTURE LIMITED',
 'Whirlpool of India Limited',
 'The Rai Saheb Rekhchand Mohota Spinning & Weaving Mills Ltd.',
 'WIM PLAST LTD.',
 'WILLIAMSON MAGOR & COMPANY LIMI',
 'WELSPUN SYNTEX',
 'LAKSHMI MACHINE WORKS LIMITED',
 'Wockhardt Limited',
 'WEST LEISURE RESORTS LTD',
 'WOCKHARDT INR5',
 'WINMORE SILK MILLS LTD.',
 'Wintac Ltd.',
 'INDIABULLS WHOLESALE SERVICES L',
 'WEIZMANN LTD.',
 'WEIZMANN INR10',
 'WHITE HALL COMMERCIAL CO.LTD.',
 'Whirlpool of India Limited',
 'Williamson Magor & Co. Limited',
 'ADOR WELDING LTD.',
 'Wendt (India) Limited',
 'Zydus Wellness Limited',
 'KHATAU MAKANJI SPG.& WVG.CO.LT',
 'West Coast Paper Mills Limited',
 'Wires & Fabriks (S.A.) Limited',
 'TODAYS WRITING INS INR10',
 'ACE TOURS WORLDWIDE LTD',
 'Welcure Drugs & Pharmaceuticals Ltd.',
 'Bombay Talkies Ltd',
 'STEEL STRIPS WHEELS LTD.',
 'TITAGARH WAGONS LTD.',
 'ENKEI WHEELS (INDIA) LTD.',
 'Welspun Enterprises Limited',
 "Today's Writing Instruments Limited",
 'WOOLWAYS (INDIA) LTD.',
 'Modella Woollens Limited',
 'Wanbury Ltd.',
 'Winsome Breweries Limited',
 'WOPOLIN PLASTICS LTD.',
 'Vikas WSP Limited',
 'Shalimar Wires Industries Ltd',
 'Steel Strips Wheels Limited',
 'WELSPUN ENTERPRISES LIMTED',
 'DOWELLS ELEKTRO WERKE LTD.',
 'Wonderla Holidays Limited',
 'XPRO INDIA LTD.',
 'RELIANCE CAPITAL A FHF XXI SER',
 'XCHANGING SOLUTIONS LIMITED',
 'Excel Glasses Limited',
 'Xchanging Solutions Limited',
 'FIVE X FINANCE & INVESTMENT LT',
 'UTI MUTUAL FUND FTI XII-X 1096D',
 'Saral Mining Limited',
 'XCHANGING SOLUTIONS LTD.',
 'XL ENERGY LTD.',
 'XL Energy Limited',
 'Yuken India Limited',
 'Yogi Infra Projects Limited',
 'Yes Bank Limited',
 'Yashraj Containeurs Ltd',
 'Citizen Yarns Limited',
 'Andrew Yule & Company Ltd.',
 'YURANUS INFRASTRUCTURE LTD',
 'YKM INDUSTRIES LTD.',
 'Sharad Fibres and Yarn Processors Limited',
 'Rishab Special Yarns Limited',
 'YES BANK LIMITED',
 'YAMINI INVESTMENTS COMPANY LTD',
 'CT COTTON YARN LTD.',
 'YORK EXPORTS LTD.',
 'Yash Management and Satellite Ltd.',
 'YANTRA NATURAL RESOURCES LTD.',
 'YULE FINANCING & LEASING CO.LT',
 'Yarn Syndicate Limited',
 'WINSOME YARNS LTD INR10',
 'YENEPOYA MINERALS & GRANITES L',
 'YASH TRADING & FINANCE LTD.',
 'SHREE YAAX PHARMA & COSMETICS',
 'YESBANK4.BO',
 'WINSOME YARNS LTD.',
 'Oswal Yarns Ltd.',
 'Winsome Yarns Limited',
 'YUVRAJ INTERNATIONAL LTD.',
 'YOGI POLYESTERS LTD.',
 'YUVRAAJ HYGIENE PRODUCTS LTD.',
 'Yogya Enterprises Limited',
 'Padam Cotton Yarns Limited',
 'Zylog Systems Limited',
 'Zylog Systems Limited',
 'S.V.TRADING & AGENCIES LTD.',
 'SARASWATI COMMERCIAL (INDIA) L',
 'INDUCON INDIA LTD.',
 'ZIGMA SOFTWARE LTD.',
 'Zensar Technologies Limited',
 'Binayak Tex Processors Limited',
 'Hindustan Zinc Limited',
 'SVARAJ TRADING & AGENCIES LTD.',
 'SURYODAYA INVESTMENT & TRADING',
 'Zandu Realty Limited',
 'Zenith Exports Limited',
 'Dhanvantri Jeevan Rekha Ltd',
 'Khandelwal Extractions Ltd.',
 'GOLD ROCK INVESTMENTS LTD.',
 'SOMESHWARA CEMENTS & CHEMICALS',
 'ZENITH EXPORTS LTD INR10',
 'ZENITH INFOTECH LTD.',
 'ZUARI AGRO CHEMICALS LTD.',
 'SATYAM SILK MILLS LTD.',
 'Hindustan Zinc Ltd.',
 'ZEE LEARN LIMITED',
 'ZEEMEDIA6.BO',
 'ZODIAC-JRD-MKJ LTD.',
 'ZEE ENTERTAIN ENT 6% CUM RED NO',
 'ZILLION PHARMACHEM LTD.',
 'ZENTECH*',
 'BHILAI ENGINEERING CORPORATION',
 'BIHAR AIR PRODUCTS LTD.',
 'ZHINDBRE.BO',
 'HINDUSTAN HOUSING CO.LTD.',
 'SAMPADA CHEMICALS LTD.',
 'TRIBHOVANDAS BHIMJI ZAVERI LTD',
 'KOVALAM INVESTMENT & TRADING C',
 'ROSE ZINC LTD.',
 'GAEKWAR MILLS LTD.',
 'SWASTIK SAFE DEPOSIT & INVESTM',
 'ZENSAR TECHNOLOGIES LTD.',
 'ZODIAC CLOTHING CO.LTD.',
 'GOLKONDA ENGINEERING ENTERPRIS',
 'HINDZINC4.BO',
 'Mewat Zinc Ltd.',
 'ZENITH COMPUTERS LTD.',
 'VVN MFG.& INVESTA LTD.',
 'ZENITH EXPORTS LTD.',
 'Tribhovandas Bhimji Zaveri Limited',
 'Zee Entertainment Enterprises Limited',
 'Z.F.STEERING GEAR (INDIA) LTD.',
 'MANSOON TRADING CO.LTD.',
 'Zuari Global Limited',
 'SANCHANA TRADING & FINANCE LTD',
 'ZUARI GLOBAL LTD.',
 'HEM HOLDINGS & TRADING LTD.',
 'ARDI INVESTMENT & TRADING LTD.',
 'MULTIPURPOSE TRADING & AGENCIE',
 'Zyden Gentec Ltd.',
 'ZICOM ELECTRONIC SECURITY SYSTE',
 'JEET MACHINE TOOLS LTD.',
 'ZEE ENT*',
 'PRABHU STEEL INDUSTRIES LTD.',
 'SNEH CONSTRUCTION LTD.',
 'Exdon Trading Company Limited',
 'ZEE LEARN LTD.',
 'CHANAKYA INVESTMENTS LTD.',
 'SANMITRA COMMERCIAL LTD.',
 'DIGITAL ELECTRONICS LTD.',
 'Zenith Computers Limited',
 'SPEEDAGE COMMERCIALS LTD.',
 'BALGOPAL HOLDING & TRADERS LTD',
 'ARCO LEASING LTD.',
 'SOMAIYA ORGANICS (INDIA) LTD.',
 'PARASRAMPURIA POLYAMIDES LTD.',
 'ZEE MEDIA CORPORATION LIMITED',
 'NIVI TRADING LTD.',
 'Zee Media Corporation Limited',
 'NILKANTH ENGINEERING LTD.',
 'MILGRAY FINANCE & INVESTMENT L',
 'AMBIKA SILK MILLS LTD.',
 'ZANDU REALTY LIMITED',
 'HIMATSINGKA MOTOR WORKS LTD.',
 'Zuari Agro Chemicals Limited',
 'SRI CHAKRA FINANCIAL SERVICES',
 'ZODIAC VENTURES LIMITED',
 'Zee Learn Limited',
 'Zen Technologies Limited',
 'KHATAU EXIM LTD.',
 'WARDEN CONSTRUCTION & FINANCE',
 'BHAVI INVESTMENTS LTD.',
 'GOVIND POY OXYGEN LTD.',
 'SOUTHERN GAS LTD.',
 'LEENA CONSULTANCY LTD.',
 'Zen Technologies Limited',
 'SARVAMANGAL MERCANTILE CO.LTD.',
 'ZEN TECHNOLOGIES INR1',
 'DOLPHIN INVESTMENTS LTD.',
 'ZYDUSWELL6.BO',
 "Planter's Polysacks Limited",
 'ZENERGY LTD.',
 'ZENITH BIRLA(INDIA INR10',
 'ZENITH CAPITALS LTD.',
 'Zen Technologies Ltd.',
 'ZODIAC CLOTHING COMPANY LIMITED',
 'ZANDU REALTY LIMITED',
 'Zensar Technologies Limited',
 'ZEE ENTERTAINMENT ENTERPRISES',
 'HINDUSTAN ZINC LIMITED',
 'SUNRISE ZINC LTD.',
 'Zodiac Clothing Company Limited',
 'ZYDUS WELLNESS LIMITED',
 'Zenith Fibres Ltd.',
 'HINDUSTHAN UDYOG LTD.',
 'SAM-TUL INVESTMENTS LTD.',
 'ZEN TECH*',
 'ZENITH BIRLA (INDIA) LTD.',
 'Parichay Investments Limited',
 'SIMCO TRADING & FINANCE CO.LTD',
 'Zicom Electronic Security Systems Limited',
 'ZENITHSTL.BO',
 'PESTICIDES & BREWERIES LTD.',
 'Aarvee Denims and Exports Limited',
 'AARTI DRUGS LTD.',
 'AAKAR ENGINEERING & MANUFACTUR',
 'CMM BROADCASTING NETWORK LTD.',
 'AAGAM CAPITAL LTD.',
 'Jainex Aamcol Ltd.',
 'AARTI DRUGS LTD INR10',
 'AARTI INDUSTRIES LIMITED',
 'AARYA GLOBAL SHARES AND SECURI',
 'AASWA TRADING & EXPORTS LTD.',
 'AASHEE INFOTECH LTD.',
 'Aayush Food And Herbs Limited',
 'AAR COMMERCIAL COMPANY LIMITED',
 'Aarti Industries Limited',
 'Aananda Lakshmi Spinning Mills',
 'AARTI INDUSTRIES LTD.',
 'Aarey Drugs & Pharmaceuticals Ltd.',
 'Aarti Drugs Limited',
 'AASHEESH SECURITIES LTD.',
 'Aadi Industries Limited',
 'AARVEE DENIMS & EXPORTS LTD.',
 'Aanchal Ispat Limited',
 'ABC Gas (International) Ltd.',
 'Aditya Birla Chemicals (India) Limited',
 'ABB4.BO',
 'ABB India Limited',
 'ABB India Limited',
 ]

# Convert to a set for faster lookup
stock_names_set = set(stock_names)

# %%
import re

def find_stock_names_in_text(news_text, stock_names_set):
    # Create a regular expression pattern from the stock names
    pattern = r'\b(?:' + '|'.join(map(re.escape, stock_names_set)) + r')\b'
    
    # Find all matching stock names in the news article
    matches = re.findall(pattern, news_text, flags=re.IGNORECASE)  # Ignore case sensitivity
    
    return set(matches)  # Return unique matches as a set

# Example news article
news_text = """
agri pick report december geojit financial service id objectidecbbfeabced title agri pick report december geojit financial service desc according geojit financial service national commodity derivative exchange monday said would live trading session feb account presentation union budget aprmar date december datetime december ist content geojit financial services report daily agri pick national commodity derivative exchange monday said would live trading session feb account presentation union budget aprmar farmer karnataka sown rabi crop million hectare saturday year million hectare sown corresponding period last year according report released state agriculture government chana acreage state rose nearly year million hectare hectare sown last year acreage horse gram kulthi dal hectare hectare last year report showed total area sown pulse million hectare million hectare year ago jowar wheat chana onion chilli key crop grown state rabi season according report state set target sowing rabi crop million hectare season covered acreage jowar saturday hectare hectare year ago according report area sown wheat hectare hectare sown last year maize rose hectare hectare last year total area sown oilseed hectare far hectare sown period last year according report oilseed acreage groundnut rose hectare hectare previous year sugarcane acreage state far hectare hectare sown year ago report showed saturday state received mm rainfall since oct northeast monsoon season normal rainfall mm report showeddesc geojit financial services report daily agri pick national commodity derivative exchange monday said would live trading session feb account presentation union budget aprmar farmer karnataka sown rabi crop million hectare saturday year million hectare sown corresponding period last year according report released state agriculture government chana acreage state rose nearly year million hectare hectare sown last year acreage horse gram kulthi dal hectare hectare last year report showed total area sown pulse million hectare million hectare year ago jowar wheat chana onion chilli key crop grown state rabi season according report state set target sowing rabi crop million hectare season covered acreage jowar saturday hectare hectare year ago according report area sown wheat hectare hectare sown last year maize rose hectare hectare last year total area sown oilseed hectare far hectare sown period last year according report oilseed acreage groundnut rose hectare hectare previous year sugarcane acreage state far hectare hectare sown year ago report showed saturday state received mm rainfall since oct northeast monsoon season normal rainfall mm report showed
"""

# Call the function
matched_stocks = find_stock_names_in_text(news_text, stock_names_set)
print(matched_stocks)  # Output: {'Apple', 'MSFT', 'Tesla'}
# Out:
# set()
